# %% [markdown]
# # BBC NEWS ARTICLE SUMMARIZATION

# %% [markdown]
# ### Import libraries

# %%
import os
import pandas as pd
from transformers import T5ForConditionalGeneration, T5Tokenizer

# %% [markdown]
# ### Load the text files from the directory

# %%
# Define the directory of the files
files_directory = "data/entertainment"

# Create an empty list to store DataFrames
dataframes = []

# Loop through all text files in the directory
for filename in os.listdir(files_directory):
    if filename.endswith(".txt"):
        file_path = os.path.join(files_directory, filename)
        
        # Read the text from the file
        with open(file_path, "r", encoding="utf-8") as file:
            text = file.read()
        
        # Create a DataFrame for each file
        dataset = pd.DataFrame({"Name": [filename], "Text": [text]})
        dataframes.append(dataset)

# Concatenate the list of DataFrames into one DataFrame
texts_data = pd.concat(dataframes, ignore_index=True)

# Display the DataFrame to explore the text content
texts_data.head(10)
# Out:
#       Name                                               Text
# 0  001.txt  Gallery unveils interactive tree\n\nA Christma...
# 1  002.txt  Jarre joins fairytale celebration\n\nFrench mu...
# 2  003.txt  Musical treatment for Capra film\n\nThe classi...
# 3  004.txt  Richard and Judy choose top books\n\nThe 10 au...
# 4  005.txt  Poppins musical gets flying start\n\nThe stage...
# 5  006.txt  Bennett play takes theatre prizes\n\nThe Histo...
# 6  007.txt  Levy tipped for Whitbread prize\n\nNovelist An...
# 7  008.txt  West End to honour finest shows\n\nThe West En...
# 8  009.txt  Da Vinci Code is 'lousy history'\n\nThe plot o...
# 9  010.txt  Uganda bans Vagina Monologues\n\nUganda's auth...

# %% [markdown]
# ### Explore the data

# %%
texts_data.Text[0]
# Out:
# 'Gallery unveils interactive tree\n\nA Christmas tree that can receive text messages has been unveiled at London\'s Tate Britain art gallery.\n\nThe spruce has an antenna which can receive Bluetooth texts sent by visitors to the Tate. The messages will be "unwrapped" by sculptor Richard Wentworth, who is responsible for decorating the tree with broken plates and light bulbs. It is the 17th year that the gallery has invited an artist to dress their Christmas tree. Artists who have decorated the Tate tree in previous years include Tracey Emin in 2002.\n\nThe plain green Norway spruce is displayed in the gallery\'s foyer. Its light bulb adornments are dimmed, ordinary domestic ones joined together with string. The plates decorating the branches will be auctioned off for the children\'s charity ArtWorks. Wentworth worked as an assistant to sculptor Henry Moore in the late 1960s. His reputation as a sculptor grew in the 1980s, while he has been one of the most influential teachers during the last two decades. Wentworth is also known for his photography of mundane, everyday subjects such as a cigarette packet jammed under the wonky leg of a table.\n'

# %%
# getting the information of the data
texts_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    386 non-null    object
#  1   Text    386 non-null    object
# dtypes: object(2)
# memory usage: 6.2+ KB

# %%
# checking for null value
texts_data.isna().sum()
# Out:
# Name    0
# Text    0
# dtype: int64

# %%
# limiting the number of data for easy tokenization and summary
texts_data = texts_data.iloc[0:50] 
texts_data
# Out:
#        Name                                               Text
# 0   001.txt  Gallery unveils interactive tree\n\nA Christma...
# 1   002.txt  Jarre joins fairytale celebration\n\nFrench mu...
# 2   003.txt  Musical treatment for Capra film\n\nThe classi...
# 3   004.txt  Richard and Judy choose top books\n\nThe 10 au...
# 4   005.txt  Poppins musical gets flying start\n\nThe stage...
# 5   006.txt  Bennett play takes theatre prizes\n\nThe Histo...
# 6   007.txt  Levy tipped for Whitbread prize\n\nNovelist An...
# 7   008.txt  West End to honour finest shows\n\nThe West En...
# 8   009.txt  Da Vinci Code is 'lousy history'\n\nThe plot o...
# 9   010.txt  Uganda bans Vagina Monologues\n\nUganda's auth...
# 10  011.txt  Artists' secret postcards on sale\n\nPostcards...
# 11  012.txt  Neeson in bid to revive theatre\n\nHollywood f...
# 12  013.txt  Levy takes Whitbread novel prize\n\nOrange Pri...
# 13  014.txt  Adventure tale tops awards\n\nYoung book fans ...
# 14  015.txt  Mutant book wins Guardian prize\n\nA book abou...
# 15  016.txt  Arthur Hailey: King of the bestsellers\n\nNove...
# 16  017.txt  Spark heads world Booker list\n\nDame Muriel S...
# 17  018.txt  Versace art portfolio up for sale\n\nThe art c...
# 18  019.txt  Slater to star in Broadway play\n\nActor Chris...
# 19  020.txt  Public show for Reynolds portrait\n\nSir Joshu...
# 20  021.txt  Obituary: Dame Alicia Markova\n\nDame Alicia M...
# 21  022.txt  Fears raised over ballet future\n\nFewer child...
# 22  023.txt  Famed music director Viotti dies\n\nConductor ...
# 23  024.txt  Paraguay novel wins US book prize\n\nA novel s...
# 24  025.txt  New Harry Potter tops book chart\n\nHarry Pott...
# 25  026.txt  UK's National Gallery in the pink\n\nThe Natio...
# 26  027.txt  Lit Idol begins search for author\n\nThe secon...
# 27  028.txt  Potter director signs Warner deal\n\nHarry Pot...
# 28  029.txt  Baghdad Blogger on big screen\n\nA film based ...
# 29  030.txt  US critics laud comedy Sideways\n\nRoad trip c...
# 30  031.txt  Dirty Den's demise seen by 14m\n\nMore than 14...
# 31  032.txt  Redford's vision of Sundance\n\nDespite sporti...
# 32  033.txt  DVD review: Harry Potter and the Prisoner of A...
# 33  034.txt  Vera Drake scoops film award\n\nOscar hopefuls...
# 34  035.txt  Hundreds vie for best film Oscar\n\nA total of...
# 35  036.txt  Hanks greeted at wintry premiere\n\nHollywood ...
# 36  037.txt  Film row over Pirates 'cannibals'\n\nPlans to ...
# 37  038.txt  Stars gear up for Bafta ceremony\n\nFilm stars...
# 38  039.txt  Aviator 'creator' in Oscars snub\n\nThe man wh...
# 39  040.txt  Wine comedy up for six film gongs\n\nSideways,...
# 40  041.txt  No ads for Passion Oscar campaign\n\nProducer ...
# 41  042.txt  Berlin honours S Korean director\n\nSouth Kore...
# 42  043.txt  Stars pay tribute to actor Davis\n\nHollywood ...
# 43  044.txt  US actor Ossie Davis found dead\n\nUS actor Os...
# 44  045.txt  Jugnot 'tops French actor league'\n\nActor Ger...
# 45  046.txt  Howl helps boost Japan's cinemas\n\nJapan's bo...
# 46  047.txt  Berlin applauds Hotel Rwanda\n\nPolitical thri...
# 47  048.txt  'Landmark movies' of 2004 hailed\n\nUS film pr...
# 48  049.txt  De Niro film leads US box office\n\nFilm star ...
# 49  050.txt  Willis sues over movie 'injury'\n\nActor Bruce...

# %% [markdown]
# ### Initialize the T5 model and tokenizer

# %%
model = T5ForConditionalGeneration.from_pretrained("t5-small")
tokenizer = T5Tokenizer.from_pretrained("t5-small")

# %% [markdown]
# ### Create a DataFrame to store the summaries

# %%
texts_data["Summary"] = ""

# %% [markdown]
# ### Tokenize and summarize the text

# %%
# Initialize the model once for better performance
model.eval()

# Iterate through the rows of the DataFrame
for index, row in texts_data.iterrows():
    text = row["Text"]
    
    # Tokenize and summarize the text
    input_ids = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=1024, truncation=True)
    summary_ids = model.generate(input_ids, max_length=150, min_length=30, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    
    # Update the "Summary" column with the generated summary
    texts_data.at[index, "Summary"] = summary

# %% [markdown]
# ### View Summary

# %%
texts_data.head(10)
# Out:
#       Name                                               Text  \
# 0  001.txt  Gallery unveils interactive tree\n\nA Christma...
# 1  002.txt  Jarre joins fairytale celebration\n\nFrench mu...
# 2  003.txt  Musical treatment for Capra film\n\nThe classi...
# 3  004.txt  Richard and Judy choose top books\n\nThe 10 au...
# 4  005.txt  Poppins musical gets flying start\n\nThe stage...
# 5  006.txt  Bennett play takes theatre prizes\n\nThe Histo...
# 6  007.txt  Levy tipped for Whitbread prize\n\nNovelist An...
# 7  008.txt  West End to honour finest shows\n\nThe West En...
# 8  009.txt  Da Vinci Code is 'lousy history'\n\nThe plot o...
# 9  010.txt  Uganda bans Vagina Monologues\n\nUganda's auth...
#
#                                              Summary
# 0  the spruce has an antenna which can receive Bl...
# 1  "Christian Andersen's fairy tales are timeless...
# 2  the musical is being turned into a musical by ...
# 3  the 10 authors shortlisted for a Richard and J...
# 4  the stage adaptation of children's film Mary P...
# 5  The History Boys by Alan Bennett takes theatre...
# 6  Andrea Levy is favourite to win the main Whitb...
# 7  the Producers, starring Nathan Lane and Lee Ev...
# 8  the da Vinci Code claims Jesus was not crucifi...
# 9  the play is due to open in the capital, Kampal...

# %% [markdown]
# ### Save the DataFrame with summaries to a CSV file

# %%
texts_data.to_csv("summaries.csv", index=False)
